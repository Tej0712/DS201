# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df=pd.read_csv('USvideos.csv')

# %%
df.head(20)
# Out:
#        video_id trending_date  \
# 0   2kyS6SvSYSE      17.14.11
# 1   1ZAPwfrtAFY      17.14.11
# 2   5qpjK5DgCt4      17.14.11
# 3   puqaWrEC7tY      17.14.11
# 4   d380meD0W0M      17.14.11
# 5   gHZ1Qz0KiKM      17.14.11
# 6   39idVpFF7NQ      17.14.11
# 7   nc99ccSXST0      17.14.11
# 8   jr9QtXwC9vc      17.14.11
# 9   TUmyygCMMGA      17.14.11
# 10  9wRQljFNDW8      17.14.11
# 11  VifQlJit6A0      17.14.11
# 12  5E4ZBSInqUU      17.14.11
# 13  GgVmn66oK_A      17.14.11
# 14  TaTleo4cOs8      17.14.11
# 15  kgaO45SyaO4      17.14.11
# 16  ZAQs-ctOqXQ      17.14.11
# 17  YVfyYrEmzgM      17.14.11
# 18  eNSN6qet1kE      17.14.11
# 19  B5HORANmzHw      17.14.11
#
#                                                 title          channel_title  \
# 0                  WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1   The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2   Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24951 entries, 0 to 24950
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                24951 non-null  object
#  1   trending_date           24951 non-null  object
#  2   title                   24951 non-null  object
#  3   channel_title           24951 non-null  object
#  4   category_id             24951 non-null  int64
#  5   publish_time            24951 non-null  object
#  6   tags                    24951 non-null  object
#  7   views                   24951 non-null  int64
#  8   likes                   24951 non-null  int64
#  9   dislikes                24951 non-null  int64
#  10  comment_count           24951 non-null  int64
#  11  thumbnail_link          24951 non-null  object
#  12  comments_disabled       24951 non-null  bool
#  13  ratings_disabled        24951 non-null  bool
# ...

# %%
df.shape
# Out:
# (24951, 16)

# %%
df1=df.drop_duplicates()

# %%
df1.shape
# Out:
# (24951, 16)

# %%
df1.corr
# Out:
# <bound method DataFrame.corr of           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 24946  5bJ_gb19pKQ      18.20.03
# 24947  Ek3aeUhHaFY      18.20.03
# 24948  fzmM0AB60QQ      18.20.03
# 24949  ESyJop31cmY      18.20.03
# 24950  305ryPvU6A8      18.20.03
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 24946                   Honest Trailers - Thor: Ragnarok
# 24947                         Primitive Technology: Lime
# ...

# %%
df2 = df1[["views", "likes", "category_id"]]

# %%
df2
# Out:
#          views   likes  category_id
# 0       748374   57527           22
# 1      2418783   97185           24
# 2      3191434  146033           23
# 3       343168   10172           24
# 4      2095731  132235           24
# ...        ...     ...          ...
# 24946  3259936   87201            1
# 24947  4289238  135901           22
# 24948  2929814   37999           24
# 24949   380230   32022           22
# 24950  7365395   98457           28
#
# [24951 rows x 3 columns]

# %%
df2.corr()
# Out:
#                 views     likes  category_id
# views        1.000000  0.794761    -0.126534
# likes        0.794761  1.000000    -0.134979
# category_id -0.126534 -0.134979     1.000000

# %%
df1.nlargest(100,"views")
# Out:
#           video_id trending_date  \
# 6181   FlsCjmMhFmw      17.14.12
# 5935   FlsCjmMhFmw      17.13.12
# 5699   FlsCjmMhFmw      17.12.12
# 5452   FlsCjmMhFmw      17.11.12
# 2587   TyHvyGVs42U      17.26.11
# ...            ...           ...
# 5417   vn9mMeWcgoM      17.11.12
# 19688  YBpdL9hSac4      18.22.02
# 4503   817P8W8-mGE      17.06.12
# 15192  VRJmcxCrAOA      18.30.01
# 5195   SM1w9PEQOE8      17.09.12
#
#                                                    title       channel_title  \
# 6181   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   YouTube Spotlight
# 5935   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   YouTube Spotlight
# 5699   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   YouTube Spotlight
# 5452   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   YouTube Spotlight
# 2587           Luis Fonsi, Demi Lovato - Échame La Culpa       LuisFonsiVEVO
# ...                                                  ...                 ...
# ...

# %%
df1.nlargest(10,['likes','views'])
# Out:
#           video_id trending_date  \
# 6181   FlsCjmMhFmw      17.14.12
# 5935   FlsCjmMhFmw      17.13.12
# 5699   FlsCjmMhFmw      17.12.12
# 5452   FlsCjmMhFmw      17.11.12
# 3581   kTlv5_Bs8aw      17.01.12
# 3349   kTlv5_Bs8aw      17.30.11
# 22040  OK3GJ0WIQ8s      18.06.03
# 5236   FlsCjmMhFmw      17.10.12
# 21813  OK3GJ0WIQ8s      18.05.03
# 4997   6ZfuNTqbHE8      17.08.12
#
#                                                    title  \
# 6181   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5935   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5699   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5452   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 3581   BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# 3349   BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# 22040                         j-hope 'Daydream (백일몽)' MV
# 5236   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 21813                         j-hope 'Daydream (백일몽)' MV
# ...

# %%
df_top100views=df1.nlargest(100,"views")

# %%
df_top100views
# Out:
#           video_id trending_date  \
# 6181   FlsCjmMhFmw      17.14.12
# 5935   FlsCjmMhFmw      17.13.12
# 5699   FlsCjmMhFmw      17.12.12
# 5452   FlsCjmMhFmw      17.11.12
# 2587   TyHvyGVs42U      17.26.11
# ...            ...           ...
# 5417   vn9mMeWcgoM      17.11.12
# 19688  YBpdL9hSac4      18.22.02
# 4503   817P8W8-mGE      17.06.12
# 15192  VRJmcxCrAOA      18.30.01
# 5195   SM1w9PEQOE8      17.09.12
#
#                                                    title       channel_title  \
# 6181   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   YouTube Spotlight
# 5935   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   YouTube Spotlight
# 5699   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   YouTube Spotlight
# 5452   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   YouTube Spotlight
# 2587           Luis Fonsi, Demi Lovato - Échame La Culpa       LuisFonsiVEVO
# ...                                                  ...                 ...
# ...

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
sns.pairplot(df_1,vars=["views","likes","category_id"],hue="category_id",diag_kind="hist",palette="deep")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df_top100views,vars=["views","likes","category_id"],hue="category_id",diag_kind="hist",palette="bright")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# "In the initial example, the 'df_1' DataFrame serves as the input for the data. By setting the 'palette' option to 'deep', we're opting for a palette that provides richer, more saturated colors. The generated plot will display histograms along the diagonal while the other cells will contain scatter plots. The 'category_id' column is used to assign unique colors to data points, ensuring each category is distinguished by its own hue."
