# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('drinks.csv')

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.loc[(df['continent'] == 'Europe') & (df['beer_servings'] > 50)]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 9               Austria            279               75            191
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# ...

# %%
df.loc[(df['continent'] == 'Europe') & (df['beer_servings'] > 50), ['country']]
# Out:
#                 country
# 1               Albania
# 3               Andorra
# 9               Austria
# 15              Belarus
# 16              Belgium
# 21   Bosnia-Herzegovina
# 25             Bulgaria
# 42              Croatia
# 44               Cyprus
# 45       Czech Republic
# 48              Denmark
# 57              Estonia
# 60              Finland
# 61               France
# 64              Georgia
# 65              Germany
# 67               Greece
# 75              Hungary
# 76              Iceland
# 81              Ireland
# 83                Italy
# 93               Latvia
# 98            Lithuania
# 99           Luxembourg
# 105               Malta
# 120         Netherlands
# 126              Norway
# 135              Poland
# 136            Portugal
# 139             Moldova
# 140             Romania
# 151              Serbia
# 155            Slovakia
# 156            Slovenia
# 160               Spain
# 165              Sweden
# 166         Switzerland
# ...

# %%
df2 = df. groupby(['continent']) .size()

# %%
df2.plot.bar()
plt.show( )

# %%
df3 = df. groupby(['continent']).beer_servings.sum()

# %%
df3.plot.bar()
plt.show()

# %%
df4 = df. groupby(['continent']).beer_servings.mean()

# %%
df4
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
df4.plot.bar()
plt.show()

# %%
df5 = df. boxplot(column='beer_servings', by = 'continent',rot=45, figsize=(10,7), fontsize=15, grid = False)
plt.show()
